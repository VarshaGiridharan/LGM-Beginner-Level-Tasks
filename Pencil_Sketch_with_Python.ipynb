# %% [markdown]
# **LGM VIP INTERNSHIP Image to Pencil Sketch with Python BEGINNER LEVEL TASK 3**
#
# **VARSHA GIRIDHARAN**

# %% [markdown]
# **Step 1:** **Import Required Libraries**

# %%
import cv2
import matplotlib.pylab as plt
from google.colab.patches import cv2_imshow
from google.colab import files

# %% [markdown]
# **Step 2:** **Load the Image**

# %%
def read_file(filename):
  image = cv2.imread(filename)
  cv2_imshow(image)
  return image
uploaded = files.upload()
filename = next(iter(uploaded))
image = read_file(filename)
# Out:
#      <input type="file" id="files-d0895191-bf88-44ae-ad42-c8443654bd20" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d0895191-bf88-44ae-ad42-c8443654bd20">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving funny_cat_194619.jpg to funny_cat_194619 (1).jpg
# <PIL.Image.Image image mode=RGB size=400x600 at 0x7FF74B75A490>

# %% [markdown]
# **Step 3:** **Detect the Edges**

# %%
dst_sketch, dst_color_sketch = cv2.pencilSketch(image, sigma_s=50, sigma_r=0.07, shade_factor=0.08)
dst_water_color = cv2.stylization(image, sigma_s=50, sigma_r=0.0825)

# %% [markdown]
# **Step 4:** **Plot the Output**

# %%
plt.figure(figsize=(20,14))
plt.subplot(221), plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB)), plt.axis('off'), plt.title('Original Image', size=20)
plt.subplot(222), plt.imshow(dst_sketch, cmap='gray'), plt.axis('off'), plt.title('Pencil-Sketch', size=20)
plt.show()

# %%
plt.figure(figsize=(20,14))
plt.subplot(221), plt.imshow(cv2.cvtColor(dst_color_sketch, cv2.COLOR_BGR2RGB)), plt.axis('off'), plt.title('Color-Pencil-Sketch', size=20)
plt.subplot(222), plt.imshow(cv2.cvtColor(dst_water_color, cv2.COLOR_BGR2RGB)), plt.axis('off'), plt.title('Stylized-Color', size=20)
plt.show()

# %% [markdown]
# **Summary:** In this project we learned to read the image in RBG format and then convert it to a grayscale image. This will turn an image into a classic black and white photo. Then the next thing to do is invert the grayscale image also called negative image, this will be our inverted grayscale image. Inversion can be used to enhance details. Then we can finally create the pencil sketch by mixing the grayscale image with the inverted blurry image. This can be done by dividing the grayscale image by the inverted blurry image. Since images are just arrays, we can easily do this programmatically using the divide function from the cv2 library in Python.
